# %%
#SUPPLOTS AND AXIS
# %matplotlib notebook
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("weather.csv")
df.head()
# Out:
#    MONTH  DAY  TIME  TEMP  PRESSURE
# 0      1    1     1   6.8     10207
# 1      1    1     2   5.8     10214
# 2      1    1     3   5.7     10220
# 3      1    1     4   6.0     10225
# 4      1    1     5   4.5     10230

# %%
days=df[df['MONTH'].isin([1,7])&(df['DAY']==1)].drop('DAY',axis=1)
days.head()
# Out:
#    MONTH  TIME  TEMP  PRESSURE
# 0      1     1   6.8     10207
# 1      1     2   5.8     10214
# 2      1     3   5.7     10220
# 3      1     4   6.0     10225
# 4      1     5   4.5     10230

# %%
days=days.pivot(columns='MONTH',index='TIME')
days.head()
# Out:
#       TEMP       PRESSURE
# MONTH    1     7        1      7
# TIME
# 1      6.8  16.3    10207  10100
# 2      5.8  16.5    10214  10099
# 3      5.7  16.3    10220  10098
# 4      6.0  16.5    10225  10096
# 5      4.5  16.7    10230  10098

# %%
ax=days.plot()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
ax=days.plot(subplots=True)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
ax=days.plot(subplots=True,layout=(2,2))
ax=days.plot(subplots=True,layout=(2,2),sharey=True)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %%
fig,ax=plt.subplots(2,2,sharey='row',sharex='col')
days['TEMP'].plot(subplots=True,ax=ax[0],legend=False)
days['PRESSURE'].plot(subplots=True,ax=ax[1],legend=False)
# Out:
# <img src="data:image/png;base64,..." width="640">
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000000000C1B6C18>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000000000C239278>],
#       dtype=object)

# %%
ax[0][0].set_ylabel("TEMP")
ax[0][0].set_title("JAN")
ax[0][1].set_title("JULY")
ax[1][0].set_ylabel("Pressure")
ax[1][0].set_xlabel("TIME")
ax[1][1].set_xlabel("TIME")
fig.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-9effae840f5f> in <module>()
# ----> 1 ax[0][0].set_ylabel("TEMP")
#       2 ax[0][0].set_title("JAN")
#       3 ax[0][1].set_title("JULY")
#       4 ax[1][0].set_ylabel("Pressure")
#       5 ax[1][0].set_xlabel("TIME")
#
# NameError: name 'ax' is not defined
