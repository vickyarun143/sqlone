# %%
# %matplotlib notebook
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn-pastel')

# %%
#MAIN PROPERTIES OF AN AXIS 
#LIMITS:VALUE WHERE THE AXIS STARTS AND ENDS
#TICKS:POSITIONS OF INDICATOR LINES I=ON THE AXIS
#TICK LABELS:TEXT SHOWN AT TICKS

# %%
df=pd.read_csv('sales.csv',parse_dates=['Date'])
df['Month']=df['Date'].dt.month
sales=df.groupby(['Month','Product'])['Amount'].sum().unstack()
sales.head()
# Out:
# Product        a        b       c
# Month
# 1         7260.0   9258.0  1740.0
# 2         6534.0      NaN  5000.0
# 3         7260.0      NaN  2117.0
# 4        11616.0  13221.0  5440.0
# 5         7119.0      NaN  2990.0

# %%
styles={'a':':s','b':'--v','c':'-o'}

with plt.style.context('ggplot'):
    fig,ax=plt.subplots(figsize=(6,3))
    for column in styles:
        sales[column].dropna().plot(ax=ax,style=styles[column],grid=True,ylim=(0,2000),legend=True,label='Product'+column)
ax.set_title("Monthly sales")
ax.set_ylabel('sales(EUR)')
# Out:
# <img src="data:image/png;base64,..." width="600">
# Text(0,0.5,'sales(EUR)')

# %%
ax.set_xtricks(range(1,13))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-0f65e3824fc7> in <module>()
# ----> 1 ax.set_xtricks(range(1,13))
#
# AttributeError: 'AxesSubplot' object has no attribute 'set_xtricks'

# %%
import calendar
ax.set_xtricklabels([calendar.month_name])
